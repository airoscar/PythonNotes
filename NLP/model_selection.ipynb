# %%
import pandas as pd
# %run utils.ipynb

# %%
df = pd.read_csv('data.csv')

# %%
df['tokens'] = df['text'].apply(process_text)
df['umls_tokens'] = df['text'].apply(getUMLSTokens)

# %%
# df.to_csv('data_tokenized.csv', index=False)

# %%
value_distribution = df.loc[:,"dyslipidemia":"readmission"].apply(pd.value_counts).transpose()
value_distribution
# Out:
#                             Maybe       No      Yes
# dyslipidemia                 3.00 1,948.00 1,011.00
# fluid_electrolyte_disorder    nan 2,256.00   706.00
# obesity                      4.00 2,240.00   718.00
# cancer                      11.00 2,078.00   873.00
# peptic_ulcer                 6.00 1,988.00   968.00
# hypertension                 2.00 1,512.00 1,448.00
# readmission                   nan 2,199.00   763.00

# %%
import pandas as pd

'''Features'''
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import label_binarize

'''Classifiers'''
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier

'''Metrics/Evaluation'''
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, confusion_matrix
from scipy import interp
from itertools import cycle

'''Plotting'''
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

'''Display'''
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.2f}'.format

# load utility functions
# %run utils.ipynb
# Out:
# <style>.container { width:95% !important; }</style>
# Starting LanguageProcessor...
# Initializing Tokenizer...
# Initializing EmrSectionizer...
# Initializing NegationMatcher...
# Initializing MedicalPhraseMatcher...
# Initializing EmrPhraseNormalizer...
# Initializing EmrLanguagePostProcessor...
# LanguageProcessor ready: ['tagger', 'custom_sentencizer', 'emr_sectionizer', 'medical_phrase_matcher', 'emr_phrase_normalizer', 'negation_matcher', 'emr_post_processor']

# %%
def get_train_test_data(feature_col, target_col, target_mapper):
    X = get_vectorized_data(df[feature_col].astype('str'))
    y = df[target_col].map(target_mapper).values
    #Train test split with stratified sampling for evaluation
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,shuffle=True,random_state=3,stratify = y,)
    
    return X_train, y_train, X_test, y_test

# %%
def get_vectorized_data(text_array):
    
    tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2), 
                                   min_df = 2, 
                                   max_df = .95)

    X = tfidf_vectorizer.fit_transform(text_array) #features
    
    return reduce_vector_dimension(X)

# %%
def reduce_vector_dimension(X):
    lsa = TruncatedSVD(n_components=100, n_iter=10, random_state=3)
    X = lsa.fit_transform(X)
    return X

# %%
def test_multiple_classifiers(classifiers_dict, X_train, y_train, X_test, y_test, scenario_id='' ):
    model_name, ac_score_list, p_score_list, r_score_list, f1_score_list = [], [], [], [], []
    if scenario_id:
        scenario_id += ": "
    for k,v in classifiers_dict.items():   
        model_name.append(k)
        v.fit(X_train, y_train)
        y_pred = v.predict(X_test)
        ac_score_list.append(accuracy_score(y_test, y_pred))
        p_score_list.append(precision_score(y_test, y_pred, average='macro'))
        r_score_list.append(recall_score(y_test, y_pred, average='macro'))
        f1_score_list.append(f1_score(y_test, y_pred, average='macro'))
        model_comparison_df = pd.DataFrame([model_name, ac_score_list, p_score_list, r_score_list, f1_score_list]).T
        model_comparison_df.columns = ['model_name', scenario_id+'accuracy', scenario_id+'precision', scenario_id+'recall', scenario_id+'f1']
        model_comparison_df = model_comparison_df.sort_values(by=scenario_id+'f1', ascending=False)

    return model_comparison_df.set_index('model_name')

# %%
def test_multiple_features(feature_cols, target_col, target_mapper):
    results = None
    for feature_col in feature_cols:
        X_train, y_train, X_test, y_test = get_train_test_data(feature_col, target_col, target_mapper )
        results = pd.concat([test_multiple_classifiers(classifier_dict, X_train, y_train, X_test, y_test, feature_col), results], axis=1)
                             
    return results

# %%
df = pd.read_csv('data_tokenized.csv')

# %%
classifier_dict = { 
    'Stochastic Gradient Descent' : SGDClassifier(random_state=3, loss='hinge', penalty='l2', alpha=1e-3,  max_iter=5),
    'Logistic Regression': LogisticRegression(n_jobs=1, C=1e5),
    'Random Forest': RandomForestClassifier(random_state=3),
    'Decsision Tree': DecisionTreeClassifier(random_state=3),
    'AdaBoost': AdaBoostClassifier(random_state=3),
    'Gaussian Naive Bayes': GaussianNB(),
    'K Nearest Neighbor': KNeighborsClassifier(),
}

# %%
feature_col = 'tokens'
target_col = 'hypertension'
target_mapper = {"Yes": 1, "Maybe": 1, "No": 0}

X_train, y_train, X_test, y_test = get_train_test_data(feature_col, target_col, target_mapper )

test_multiple_classifiers(classifier_dict, X_train, y_train, X_test, y_test)
# Out:
#                             accuracy precision recall   f1
# model_name
# Stochastic Gradient Descent     0.70      0.70   0.70 0.70
# Random Forest                   0.66      0.66   0.66 0.66
# Logistic Regression             0.66      0.66   0.66 0.66
# AdaBoost                        0.64      0.64   0.64 0.64
# Gaussian Naive Bayes            0.63      0.63   0.63 0.63
# K Nearest Neighbor              0.62      0.62   0.62 0.62
# Decsision Tree                  0.55      0.55   0.55 0.55

# %%
target_col = 'hypertension'
feature_cols = ['tokens', 'umls_tokens']
test_multiple_features(feature_cols, target_col, target_mapper)
# Out:
#                             umls_tokens: accuracy umls_tokens: precision  \
# Logistic Regression                          0.76                   0.76
# Stochastic Gradient Descent                  0.75                   0.75
# AdaBoost                                     0.68                   0.68
# Random Forest                                0.68                   0.68
# Gaussian Naive Bayes                         0.67                   0.67
# Decsision Tree                               0.60                   0.60
# K Nearest Neighbor                           0.58                   0.58
#
#                             umls_tokens: recall umls_tokens: f1  \
# Logistic Regression                        0.76            0.76
# Stochastic Gradient Descent                0.75            0.75
# AdaBoost                                   0.68            0.68
# Random Forest                              0.68            0.68
# Gaussian Naive Bayes                       0.67            0.67
# Decsision Tree                             0.60            0.60
# K Nearest Neighbor                         0.58            0.58
#
#                             tokens: accuracy tokens: precision tokens: recall  \
# Logistic Regression                     0.66              0.66           0.66
# Stochastic Gradient Descent             0.70              0.70           0.70
# AdaBoost                                0.64              0.64           0.64
# Random Forest                           0.66              0.66           0.66
# Gaussian Naive Bayes                    0.63              0.63           0.63
# Decsision Tree                          0.55              0.55           0.55
# K Nearest Neighbor                      0.62              0.62           0.62
#
#                             tokens: f1
# Logistic Regression               0.66
# Stochastic Gradient Descent       0.70
# AdaBoost                          0.64
# Random Forest                     0.66
# Gaussian Naive Bayes              0.63
# Decsision Tree                    0.55
# K Nearest Neighbor                0.62

# %%
target_col = 'peptic_ulcer'
test_multiple_features(feature_cols, target_col, target_mapper)
# Out:
#                             umls_tokens: accuracy umls_tokens: precision  \
# Gaussian Naive Bayes                         0.65                   0.60
# Logistic Regression                          0.70                   0.65
# AdaBoost                                     0.66                   0.58
# Decsision Tree                               0.57                   0.52
# K Nearest Neighbor                           0.61                   0.51
# Stochastic Gradient Descent                  0.68                   0.65
# Random Forest                                0.67                   0.58
#
#                             umls_tokens: recall umls_tokens: f1  \
# Gaussian Naive Bayes                       0.60            0.60
# Logistic Regression                        0.60            0.60
# AdaBoost                                   0.56            0.56
# Decsision Tree                             0.52            0.52
# K Nearest Neighbor                         0.51            0.50
# Stochastic Gradient Descent                0.53            0.49
# Random Forest                              0.52            0.47
#
#                             tokens: accuracy tokens: precision tokens: recall  \
# Gaussian Naive Bayes                    0.61              0.60           0.61
# Logistic Regression                     0.70              0.66           0.61
# AdaBoost                                0.66              0.60           0.58
# Decsision Tree                          0.63              0.58           0.59
# K Nearest Neighbor                      0.66              0.59           0.57
# Stochastic Gradient Descent             0.68              0.68           0.53
# Random Forest                           0.69              0.64           0.57
#
#                             tokens: f1
# Gaussian Naive Bayes              0.60
# Logistic Regression               0.62
# AdaBoost                          0.58
# Decsision Tree                    0.59
# K Nearest Neighbor                0.57
# Stochastic Gradient Descent       0.47
# Random Forest                     0.55

# %%
target_col = 'cancer'
test_multiple_features(feature_cols, target_col, target_mapper)
# Out:
#                             umls_tokens: accuracy umls_tokens: precision  \
# Logistic Regression                          0.73                   0.67
# K Nearest Neighbor                           0.72                   0.65
# Gaussian Naive Bayes                         0.69                   0.62
# AdaBoost                                     0.70                   0.61
# Decsision Tree                               0.63                   0.57
# Stochastic Gradient Descent                  0.74                   0.74
# Random Forest                                0.73                   0.72
#
#                             umls_tokens: recall umls_tokens: f1  \
# Logistic Regression                        0.61            0.62
# K Nearest Neighbor                         0.60            0.61
# Gaussian Naive Bayes                       0.60            0.61
# AdaBoost                                   0.58            0.58
# Decsision Tree                             0.57            0.57
# Stochastic Gradient Descent                0.58            0.56
# Random Forest                              0.57            0.56
#
#                             tokens: accuracy tokens: precision tokens: recall  \
# Logistic Regression                     0.82              0.81           0.73
# K Nearest Neighbor                      0.77              0.73           0.68
# Gaussian Naive Bayes                    0.76              0.72           0.68
# AdaBoost                                0.77              0.72           0.69
# Decsision Tree                          0.69              0.63           0.63
# Stochastic Gradient Descent             0.80              0.84           0.67
# Random Forest                           0.79              0.80           0.68
#
#                             tokens: f1
# Logistic Regression               0.75
# K Nearest Neighbor                0.70
# Gaussian Naive Bayes              0.69
# AdaBoost                          0.70
# Decsision Tree                    0.63
# Stochastic Gradient Descent       0.69
# Random Forest                     0.70

# %%
target_col = 'obesity'
test_multiple_features(feature_cols, target_col, target_mapper)
# Out:
#                             umls_tokens: accuracy umls_tokens: precision  \
# Gaussian Naive Bayes                         0.69                   0.59
# AdaBoost                                     0.74                   0.60
# K Nearest Neighbor                           0.72                   0.57
# Decsision Tree                               0.65                   0.53
# Logistic Regression                          0.75                   0.62
# Random Forest                                0.75                   0.61
# Stochastic Gradient Descent                  0.76                   0.38
#
#                             umls_tokens: recall umls_tokens: f1  \
# Gaussian Naive Bayes                       0.59            0.59
# AdaBoost                                   0.55            0.55
# K Nearest Neighbor                         0.54            0.53
# Decsision Tree                             0.53            0.53
# Logistic Regression                        0.54            0.53
# Random Forest                              0.52            0.48
# Stochastic Gradient Descent                0.50            0.43
#
#                             tokens: accuracy tokens: precision tokens: recall  \
# Gaussian Naive Bayes                    0.70              0.60           0.60
# AdaBoost                                0.74              0.59           0.55
# K Nearest Neighbor                      0.72              0.59           0.56
# Decsision Tree                          0.67              0.56           0.57
# Logistic Regression                     0.75              0.63           0.58
# Random Forest                           0.75              0.64           0.55
# Stochastic Gradient Descent             0.76              0.69           0.51
#
#                             tokens: f1
# Gaussian Naive Bayes              0.60
# AdaBoost                          0.55
# K Nearest Neighbor                0.56
# Decsision Tree                    0.56
# Logistic Regression               0.58
# Random Forest                     0.55
# Stochastic Gradient Descent       0.45

# %%
target_col = 'fluid_electrolyte_disorder'
test_multiple_features(feature_cols, target_col, target_mapper)
# Out:
#                             umls_tokens: accuracy umls_tokens: precision  \
# Logistic Regression                          0.78                   0.69
# Gaussian Naive Bayes                         0.70                   0.62
# AdaBoost                                     0.76                   0.65
# K Nearest Neighbor                           0.75                   0.64
# Decsision Tree                               0.70                   0.59
# Random Forest                                0.78                   0.76
# Stochastic Gradient Descent                  0.77                   0.82
#
#                             umls_tokens: recall umls_tokens: f1  \
# Logistic Regression                        0.64            0.65
# Gaussian Naive Bayes                       0.65            0.63
# AdaBoost                                   0.61            0.62
# K Nearest Neighbor                         0.59            0.60
# Decsision Tree                             0.60            0.59
# Random Forest                              0.55            0.53
# Stochastic Gradient Descent                0.53            0.49
#
#                             tokens: accuracy tokens: precision tokens: recall  \
# Logistic Regression                     0.81              0.73           0.69
# Gaussian Naive Bayes                    0.59              0.62           0.67
# AdaBoost                                0.77              0.68           0.65
# K Nearest Neighbor                      0.76              0.65           0.60
# Decsision Tree                          0.71              0.61           0.62
# Random Forest                           0.78              0.70           0.60
# Stochastic Gradient Descent             0.78              0.75           0.54
#
#                             tokens: f1
# Logistic Regression               0.71
# Gaussian Naive Bayes              0.57
# AdaBoost                          0.66
# K Nearest Neighbor                0.61
# Decsision Tree                    0.62
# Random Forest                     0.61
# Stochastic Gradient Descent       0.51

# %%
target_col = 'dyslipidemia'
test_multiple_features(feature_cols, target_col, target_mapper)
# Out:
#                             umls_tokens: accuracy umls_tokens: precision  \
# Gaussian Naive Bayes                         0.70                   0.66
# AdaBoost                                     0.71                   0.68
# Logistic Regression                          0.72                   0.70
# Stochastic Gradient Descent                  0.73                   0.76
# K Nearest Neighbor                           0.69                   0.65
# Random Forest                                0.71                   0.71
# Decsision Tree                               0.60                   0.56
#
#                             umls_tokens: recall umls_tokens: f1  \
# Gaussian Naive Bayes                       0.65            0.66
# AdaBoost                                   0.65            0.65
# Logistic Regression                        0.64            0.65
# Stochastic Gradient Descent                0.62            0.62
# K Nearest Neighbor                         0.61            0.61
# Random Forest                              0.61            0.60
# Decsision Tree                             0.56            0.56
#
#                             tokens: accuracy tokens: precision tokens: recall  \
# Gaussian Naive Bayes                    0.71              0.68           0.68
# AdaBoost                                0.73              0.70           0.66
# Logistic Regression                     0.76              0.76           0.69
# Stochastic Gradient Descent             0.75              0.81           0.64
# K Nearest Neighbor                      0.71              0.67           0.64
# Random Forest                           0.73              0.73           0.64
# Decsision Tree                          0.62              0.58           0.58
#
#                             tokens: f1
# Gaussian Naive Bayes              0.68
# AdaBoost                          0.67
# Logistic Regression               0.70
# Stochastic Gradient Descent       0.64
# K Nearest Neighbor                0.65
# Random Forest                     0.64
# Decsision Tree                    0.58

# %%
target_col = 'readmission'
test_multiple_features(feature_cols, target_col, target_mapper)
# Out:
#                             umls_tokens: accuracy umls_tokens: precision  \
# Gaussian Naive Bayes                         0.61                   0.54
# K Nearest Neighbor                           0.71                   0.55
# Logistic Regression                          0.74                   0.64
# Decsision Tree                               0.61                   0.50
# AdaBoost                                     0.71                   0.54
# Random Forest                                0.74                   0.54
# Stochastic Gradient Descent                  0.74                   0.37
#
#                             umls_tokens: recall umls_tokens: f1  \
# Gaussian Naive Bayes                       0.55            0.54
# K Nearest Neighbor                         0.53            0.52
# Logistic Regression                        0.53            0.51
# Decsision Tree                             0.50            0.50
# AdaBoost                                   0.52            0.49
# Random Forest                              0.50            0.43
# Stochastic Gradient Descent                0.50            0.43
#
#                             tokens: accuracy tokens: precision tokens: recall  \
# Gaussian Naive Bayes                    0.59              0.60           0.62
# K Nearest Neighbor                      0.71              0.57           0.54
# Logistic Regression                     0.74              0.61           0.53
# Decsision Tree                          0.62              0.52           0.52
# AdaBoost                                0.72              0.57           0.53
# Random Forest                           0.74              0.64           0.51
# Stochastic Gradient Descent             0.74              0.37           0.50
#
#                             tokens: f1
# Gaussian Naive Bayes              0.56
# K Nearest Neighbor                0.54
# Logistic Regression               0.51
# Decsision Tree                    0.52
# AdaBoost                          0.52
# Random Forest                     0.46
# Stochastic Gradient Descent       0.43

# %%
#Hyperparameter tuning

#SGD
loss =  ['hinge', 'log']
penalty = ['l2','l1']
alpha = [1e-6, 1e-3, 1e-1, 1e0]
max_iter = [1000, 10000]
tol = [None, 1e-3]
eta0 = [0, 0.1, 0.001]

random_state = [0]

X = get_vectorized_data(df['umls_tokens'].astype('str'))
y = df['hypertension'].map({"Yes": 1, "Maybe": 1, "No": 0}).values

clf = SGDClassifier()

params = dict(loss=loss,
              penalty=penalty,
              alpha=alpha,
              max_iter=max_iter,
              tol=tol,
              random_state=random_state)

gridsearch = GridSearchCV(clf,
                          params,
                          cv = 5,
                          verbose = 1, 
                          n_jobs = -1)

sgd_best_model = gridsearch.fit(X, y)
# Out:
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 640 out of 640 | elapsed:  7.0min finished

# %%
pd.DataFrame(gridsearch.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0             0.01          0.01             0.00            0.00        0.00
# 1             0.01          0.00             0.00            0.00        0.00
# 2             0.01          0.01             0.00            0.00        0.00
# 3             0.03          0.01             0.00            0.00        0.00
# 4             0.07          0.00             0.00            0.00        0.00
# ..             ...           ...              ...             ...         ...
# 123           0.03          0.00             0.00            0.00        1.00
# 124          10.62          0.11             0.00            0.00        1.00
# 125           0.01          0.00             0.00            0.00        1.00
# 126          32.01          2.21             0.00            0.00        1.00
# 127           0.03          0.00             0.00            0.00        1.00
#
#     param_loss param_max_iter param_penalty param_random_state param_tol  \
# 0        hinge              5            l2                  0      None
# 1        hinge              5            l2                  0      0.00
# 2        hinge              5            l1                  0      None
# 3        hinge              5            l1                  0      0.00
# 4        hinge            100            l2                  0      None
# ..         ...            ...           ...                ...       ...
# 123        log           1000            l1                  0      0.00
# 124        log          10000            l2                  0      None
# 125        log          10000            l2                  0      0.00
# 126        log          10000            l1                  0      None
# 127        log          10000            l1                  0      0.00
#
#                                                 params  split0_test_score  \
# 0    {'alpha': 1e-06, 'loss': 'hinge', 'max_iter': ...               0.50
# 1    {'alpha': 1e-06, 'loss': 'hinge', 'max_iter': ...               0.50
# 2    {'alpha': 1e-06, 'loss': 'hinge', 'max_iter': ...               0.52
# 3    {'alpha': 1e-06, 'loss': 'hinge', 'max_iter': ...               0.52
# 4    {'alpha': 1e-06, 'loss': 'hinge', 'max_iter': ...               0.65
# ..                                                 ...                ...
# 123  {'alpha': 1.0, 'loss': 'log', 'max_iter': 1000...               0.51
# 124  {'alpha': 1.0, 'loss': 'log', 'max_iter': 1000...               0.51
# 125  {'alpha': 1.0, 'loss': 'log', 'max_iter': 1000...               0.51
# 126  {'alpha': 1.0, 'loss': 'log', 'max_iter': 1000...               0.51
# 127  {'alpha': 1.0, 'loss': 'log', 'max_iter': 1000...               0.51
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0                 0.72               0.71               0.70
# 1                 0.72               0.71               0.70
# 2                 0.52               0.73               0.72
# 3                 0.52               0.73               0.72
# 4                 0.75               0.57               0.66
# ..                 ...                ...                ...
# 123               0.51               0.51               0.51
# 124               0.51               0.51               0.51
# 125               0.51               0.51               0.51
# 126               0.51               0.51               0.51
# 127               0.51               0.51               0.51
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.66             0.66            0.08               47
# 1                 0.66             0.66            0.08               47
# 2                 0.67             0.63            0.09               56
# 3                 0.67             0.63            0.09               56
# 4                 0.64             0.65            0.06               49
# ..                 ...              ...             ...              ...
# 123               0.51             0.51            0.00               73
# 124               0.51             0.51            0.00               73
# 125               0.51             0.51            0.00               73
# 126               0.51             0.51            0.00               73
# 127               0.51             0.51            0.00               73
#
# [128 rows x 19 columns]

# %%
sgd_best_model.best_score_
# Out:
# 0.7555729000501344

# %%
sgd_best_model.best_estimator_
# Out:
# SGDClassifier(alpha=1e-06, max_iter=10000, random_state=0, tol=None)

# %%
#Hyperparameter tuning

#LR

penalty = ['l2','l1', 'elasticnet']
C=[1, 100, 1000, 1e5]
max_iter = [100, 1000, 10000]
random_state = [3]

X = get_vectorized_data(df['umls_tokens'].astype('str'))
y = df['hypertension'].map({"Yes": 1, "Maybe": 1, "No": 0}).values

clf = LogisticRegression()

params = dict(
              penalty=penalty,
              max_iter=max_iter,
              tol=tol,
              random_state=random_state)

gridsearch = GridSearchCV(clf,
                          params,
                          cv = 5,
                          verbose = 1, 
                          n_jobs = -1)

lr_best_model = gridsearch.fit(X, y)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 480 out of 480 | elapsed:    1.0s finished

# %%
pd.DataFrame(gridsearch.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0            0.00          0.00             0.00            0.00
# 1            0.03          0.01             0.00            0.00
# 2            0.00          0.00             0.00            0.00
# 3            0.04          0.01             0.00            0.00
# 4            0.00          0.00             0.00            0.00
# ..            ...           ...              ...             ...
# 91           0.00          0.00             0.00            0.00
# 92           0.00          0.00             0.00            0.00
# 93           0.00          0.00             0.00            0.00
# 94           0.00          0.00             0.00            0.00
# 95           0.00          0.00             0.00            0.00
#
#    param_max_iter param_penalty param_random_state param_tol  \
# 0               5            l2                  0      None
# 1               5            l2                  0      0.00
# 2               5            l2                  3      None
# 3               5            l2                  3      0.00
# 4               5            l2                 50      None
# ..            ...           ...                ...       ...
# 91          10000    elasticnet                  3      0.00
# 92          10000    elasticnet                 50      None
# 93          10000    elasticnet                 50      0.00
# 94          10000    elasticnet                 99      None
# 95          10000    elasticnet                 99      0.00
#
#                                                params  split0_test_score  \
# 0   {'max_iter': 5, 'penalty': 'l2', 'random_state...                nan
# 1   {'max_iter': 5, 'penalty': 'l2', 'random_state...               0.64
# 2   {'max_iter': 5, 'penalty': 'l2', 'random_state...                nan
# 3   {'max_iter': 5, 'penalty': 'l2', 'random_state...               0.64
# 4   {'max_iter': 5, 'penalty': 'l2', 'random_state...                nan
# ..                                                ...                ...
# 91  {'max_iter': 10000, 'penalty': 'elasticnet', '...                nan
# 92  {'max_iter': 10000, 'penalty': 'elasticnet', '...                nan
# 93  {'max_iter': 10000, 'penalty': 'elasticnet', '...                nan
# 94  {'max_iter': 10000, 'penalty': 'elasticnet', '...                nan
# 95  {'max_iter': 10000, 'penalty': 'elasticnet', '...                nan
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 nan                nan                nan
# 1                0.68               0.71               0.69
# 2                 nan                nan                nan
# 3                0.68               0.71               0.69
# 4                 nan                nan                nan
# ..                ...                ...                ...
# 91                nan                nan                nan
# 92                nan                nan                nan
# 93                nan                nan                nan
# 94                nan                nan                nan
# 95                nan                nan                nan
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 nan              nan             nan               52
# 1                0.66             0.67            0.02               13
# 2                 nan              nan             nan               72
# 3                0.66             0.67            0.02               13
# 4                 nan              nan             nan               71
# ..                ...              ...             ...              ...
# 91                nan              nan             nan               47
# 92                nan              nan             nan               49
# 93                nan              nan             nan               29
# 94                nan              nan             nan               78
# 95                nan              nan             nan               96
#
# [96 rows x 17 columns]

# %%
lr_best_model.best_score_
# Out:
# 0.730935235404038
